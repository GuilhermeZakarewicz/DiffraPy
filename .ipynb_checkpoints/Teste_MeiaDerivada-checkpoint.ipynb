# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt=.004
dx=dz=1
nt=nz=120
ntr=80 
nx=ntr
c=250

# %%
files = []

for i in range(0,80,1):
    filename = 'Data/CSG/gather_shot{}'.format(i)
    
    with open(filename, 'rb') as file:
        (gather) = np.load(file)
        files.append(gather)

# %%
shot = files[40]

plt.imshow(shot,aspect='auto',extent=[0, nx*dx, nt*dt, 0])

plt.title('Synthetic CSG with Shot at 55 m')
plt.xlabel('Distancia (m)')
plt.ylabel('Tempo (s)')
plt.show()

# %%
trace = shot[:,40]+40
t = np.arange(0,len(trace))

print(len(trace))
print(len(t))

plt.imshow(shot, aspect="auto")
plt.plot(trace,t,"k",alpha=.2)
plt.show()
# Out:
# 288
# 288

# %%
#trace = shot[:,40]+40
t = np.arange(0,len(trace))

plt.imshow(shot, aspect="auto")

traces = []
for i in range(0,len(shot[1])):
    trace = (shot[:,i]+i)
    traces.append(trace)
    plt.plot(trace,t,"k",alpha=.2)

# %%
t = np.linspace(-np.pi,np.pi,256)
s = np.sin(4*t)

plt.plot(t,s)
plt.show()

fft_s = np.fft.fft(s)
freq = np.fft.fftfreq(t.shape[-1])

plt.plot(freq,fft_s.real,freq,fft_s.imag)
#plt.xlim([-.1,.1])

# %%
trace = shot[:,40]

# %%
type(freq)
# Out:
# numpy.ndarray

# %%
fft_trace = np.fft.fft(trace)

freq = np.fft.fftfreq(trace.shape[-1])

plt.plot(freq,fft_trace.real,freq,fft_trace.imag)


trace_fft_filtered = []

for count,i in enumerate(freq):
    w = np.sqrt(i)
    trc = fft_trace[count]*w
    trace_fft_filtered.append(trc)

trace_fft_filtered = np.array(trace_fft_filtered)
plt.plot(freq,trace_fft_filtered.real,freq,trace_fft_filtered.imag)
# Out:
# <ipython-input-80-af5f232ddbe7>:11: RuntimeWarning: invalid value encountered in sqrt
#   w = np.sqrt(i)
# ...

# %%
#voltando pro domínio do tempo

trace_filtered = np.fft.ifft(trace_fft_filtered)
trace_filtered
# Out:
# array([nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
# ...
