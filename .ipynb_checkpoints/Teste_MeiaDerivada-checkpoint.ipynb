# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import MigPreFuncoes
# Out:
# Imported MigPreFuncoes now

# %%
dt=.004
dx=dz=1
nt=nz=120
ntr=80 
nx=ntr
c=250

# %%
files = []

for i in range(0,80,1):
    filename = 'Data/CSG/gather_shot{}'.format(i)
    
    with open(filename, 'rb') as file:
        (gather) = np.load(file)
        files.append(gather)

# %%
shot = files[40]

plt.imshow(shot,aspect='auto',extent=[0, nx*dx, nt*dt, 0])

plt.title('Synthetic CSG with Shot at 55 m')
plt.xlabel('Distancia (m)')
plt.ylabel('Tempo (s)')
plt.show()

# %%
trace = shot[:,40]+40
t = np.arange(0,len(trace))

print(len(trace))
print(len(t))

plt.imshow(shot, aspect="auto")
plt.plot(trace,t,"k",alpha=.2)
plt.show()

# %%
#trace = shot[:,40]+40
t = np.arange(0,len(trace))

plt.imshow(shot, aspect="auto")

traces = []
for i in range(0,len(shot[1])):
    trace = (shot[:,i]+i)
    traces.append(trace)
    plt.plot(trace,t,"k",alpha=.2)

# %%
from scipy.fft import rfft, rfftfreq, irfft
import cmath

# %%
shot = files[40] #files contem todos os gathers, escolhi o arquivo do tiro 40
trace = shot[:,40] #selecionando o traço central

# %%
#plt.plot(trace)
#plt.title("Traço Original")
#plt.show()

fft_trace = rfft(trace) #transformada do nosso traço
freq = rfftfreq(len(trace),d=dt)#*2*np.pi #bins de frequência

#plt.plot(freq,np.abs(fft_trace))
#plt.title("Espectro de Frequências do Traço")
#plt.show()

fft_new = []
for count,w in enumerate(freq): #aqui faço a multiplicação por raiz de omega
    #w = i
    #f = 1j*np.sqrt(w)*fft_trace[count]
    f = np.sqrt(w)*fft_trace[count]
    fft_new.append(f)

fft_new2 = fft_trace*np.sqrt(freq)

plt.plot(freq,np.abs(fft_new2),"k",label="Calculado")
plt.plot(freq,np.abs(fft_trace),"--r",label="Original")
plt.title("Teste Freq")
plt.legend()
plt.show()

new = irfft(fft_new2) #transformada inversa, voltando para o tempo

plt.plot(trace,"--b",label="original")
plt.plot(new,"g",label="filtrado")
plt.title("Resultado")
plt.legend()
plt.show()

# %%
#testando outra abordagem pra ver se os resultados são parecidos...
#a ideia é um phase shift de 45 graus ou pi/4

plt.plot(trace)
plt.show()

signalFFT = rfft(trace)
fftFreq = rfftfreq(len(trace))

plt.plot(fftFreq,np.abs(signalFFT))
plt.show()

## Get Power Spectral Density
signalPSD = np.abs(signalFFT) ** 2
signalPSD /= len(signalFFT)**2

plt.plot(fftFreq, signalPSD)
plt.show()

## Get Phase
signalPhase = np.angle(signalFFT)

## Phase Shift the signal +45 degrees
newSignalFFT = signalFFT * cmath.rect( 1., np.pi/4 )
newSignalFFT_teste = signalFFT * np.exp(1j*np.pi/4)

plt.plot(newSignalFFT, "k")
plt.plot(newSignalFFT_teste, "--g")
plt.title("Teste")
plt.show()

signalPhase2 = np.angle(newSignalFFT)


plt.plot(fftFreq,np.abs(newSignalFFT))
plt.show()

## Reverse Fourier transform
newSignal = irfft(newSignalFFT)

plt.plot(trace,"b",label="original")
plt.plot(newSignal,"g",label="shift de 45 graus")
plt.legend()
plt.show()

# %%
plt.plot(signalPhase[:50],"k",label="Original")
plt.plot(signalPhase2[:50],"--g",label="Calculado")
plt.legend()
plt.plot()

# %%
def phase_shift(gather):
    """
    Realiza a meia-derivada (phase-shift de 45 graus) para os traços sísmicos de um gather.
    Entrada:
    gather - dado sísmico (nt,ntr)
    Saída:
    phase_gather - dado sísmico após phase-shift em todos os traços (nt,ntr)
    """
    phase_gather = gather.copy()
    n_traces = gather.shape[-1]
    
    for i in range(n_traces):
        trace = gather[:,i] #selecionando cada traço dentro do gather
        
        signalFFT = rfft(trace) #passando o traço pro domínio da frequência
        #fftFreq = rfftfreq(len(trace)) #bins de frequência para plotar (eixo w) 
        
        signalPSD = np.abs(signalFFT) ** 2
        signalPSD /= len(signalFFT)**2

        signalPhase = np.angle(signalFFT) #fase do traço
        newSignalFFT = signalFFT * cmath.rect( 1., np.pi/4 ) #Phase Shift de 45 graus 

        newSignal = irfft(newSignalFFT) #voltando para o domínio do tempo
        
        phase_gather[:,i] = newSignal
        
    return phase_gather

# %%
phase_gather_1 = phase_shift(shot)

# %%
plt.imshow(shot, aspect="auto")
plt.title("Gather Original")
plt.colorbar()
plt.show()

plt.imshow(phase_gather_1, aspect="auto")
plt.title("Gather após Phase-Shift")
plt.colorbar()
plt.show()

# %% [markdown]
# *******
#
# ## Testando a migração

# %%
import MigPreFuncoes

# %%
with open('Data/raiosSlantStack.npy', 'rb') as f:
    TTh = np.load(f)

print(f"TTh.shape={TTh.shape}")
# Out:
# TTh.shape=(80, 120, 80)

# %%
dt=0.004
#shot_number = 40
win=20*dt
dwin=dt
app=40
isx=40

# %%
with open("Data/CSG/janela", "rb") as f:
    tst = np.load(f)
    
m_theta = np.degrees(np.arctan(tst))    
X = np.cos(m_theta) 
Y = np.sin(m_theta)

# %%
mig_winapp = MigPreFuncoes.migvsp_winapp(phase_gather_1,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

# %%
plt.imshow(mig_winapp, aspect="auto")
plt.show()

# %%
mig_winapp = MigPreFuncoes.migvsp_winapp(shot,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

plt.imshow(mig_winapp, aspect="auto")
plt.show()

# %%
mig_diff = MigPreFuncoes.migvsp_winapp_diff(shot,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

plt.imshow(mig_diff, aspect="auto")
plt.show()

# %%
mig_stack = MigPreFuncoes.migstack_winapp(files,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

plt.imshow(mig_stack, aspect="auto")
plt.show()
# Out:
# 80it [16:31, 12.40s/it]

# %%
gathers_shifted = []

for i in files:
    gather_shifted = phase_shift(i)
    gathers_shifted.append(gather_shifted)

mig_stack = MigPreFuncoes.migstack_winapp(gathers_shifted,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

plt.imshow(mig_stack, aspect="auto")
plt.show()

# %%
mig_diff = MigPreFuncoes.migvsp_winapp_diff(phase_gather_1,isx,dx,dz,dt,win,dwin,app,TTh,X,Y)

plt.imshow(mig_diff, aspect="auto")
plt.show()

# %%
def migvsp(timer,isx,dt,gather):
    [nt,ntr]=gather.shape
    [ntr2,nz,nx]=timer.shape
    if ntr!=ntr2:
        print('Gather e traveltime table tem numero diferente de traços')
    mig=np.zeros([nz,nx])
    # Loop over each trace of the shot gather at src isx
    for igx in range(0,ntr):
        #w = peso(igx,isx)
        t = timer[isx,0:nz,0:nx] + timer[igx,0:nz,0:nx]
        t2 = (t<nt)*t #Check how to avoid this... summing amplitudes for t>nt
        trace1=gather.T[np.ix_([igx],t2.flatten().astype(np.int32))]
        trace1=trace1.reshape([nz,nx])#*w
    
    return trace1

# %%
timer=np.round(TTh/dt)+1

isx=40
trace = migvsp(timer,isx,dt,shot)

# %%
plt.imshow(trace, aspect="auto")
