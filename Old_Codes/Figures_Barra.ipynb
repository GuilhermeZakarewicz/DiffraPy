# %%
import importlib
import numpy as np
import matplotlib.pyplot as plt
import MigPreFuncoes
import SlantStack
# Out:
# Imported MigPreFuncoes now
# Imported SlantStack now

# %%
importlib.reload(MigPreFuncoes)
importlib.reload(SlantStack)
# Out:
# Imported MigPreFuncoes now
# Imported SlantStack now
# <module 'SlantStack' from 'C:\\Users\\guilh\\Desktop\\Code\\SeismicDiffractions\\Old_Codes\\SlantStack.py'>

# %%
dx=1.0 #(m) Discretização em X
dz=1.0 #(m) Discretização em Y
nz=120 #Tamanho do Grid em Z
ntr=nx=240 #Tamanho do Grid em X
c=250 #m/s

# %%
MOD = np.zeros([ntr,nz])

#Barra
x_ini_1 = int(np.round(1*ntr/5))
x_fim_1 = int(np.round(4*ntr/5))

#Pontos Difratores
for i in range(x_ini_1,x_fim_1):
    z = int(np.round(nz*2/3))
    MOD[i,z]=1
MOD[int(np.round(1.5*nx/5)):int(np.round(1.5*nx/5+3)),z]=10
MOD[int(np.round(2.5*nx/5)):int(np.round(2.5*nx/5+3)),z]=10
MOD[int(np.round(3.5*nx/5)):int(np.round(3.5*nx/5+3)),z]=10

#Adicionando ruído no modelo
nn = np.random.rand(ntr,nz)
MOD = MOD+(nn-0.5)*0.2

R = MOD.T

plt.imshow(MOD.T, aspect="auto", extent=[0,dx*ntr,nz*dz,0])
plt.colorbar()
plt.show()

# %%
csfont = {'fontname':'Times New Roman'}
from mpl_toolkits.axes_grid1 import make_axes_locatable

MOD = np.zeros([ntr,nz])

#Barra
x_ini_1 = int(np.round(1*ntr/5))
x_fim_1 = int(np.round(4*ntr/5))

#Pontos Difratores
for i in range(x_ini_1,x_fim_1):
    z = int(np.round(nz*2/3))
    MOD[i,z]=1
MOD[int(np.round(1.5*nx/5)):int(np.round(1.5*nx/5+3)),z]=3
MOD[int(np.round(2.5*nx/5)):int(np.round(2.5*nx/5+3)),z]=3
MOD[int(np.round(3.5*nx/5)):int(np.round(3.5*nx/5+3)),z]=3

#Adicionando ruído no modelo
nn = np.random.rand(ntr,nz)
MOD = MOD+(nn-0.5)*0.2

R = MOD.T

fig, ax1 = plt.subplots(1,1,figsize=(8,6))

ftsize=23

im1 = ax1.imshow(R, extent=[0, nx*dx, nz*dz, 0], aspect='auto', cmap="binary", interpolation=None)
ax1.set_ylabel("Depth (m)", **csfont, fontsize=ftsize)
ax1.set_xlabel("Distance (m)", **csfont, fontsize=ftsize)

#ax1.set_ylabel("Depth (m)", **csfont, fontsize=17)
#ax1.set_xlabel("Distância (m)", **csfont, fontsize=17)

labsize=19

ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')
#ax1.tick_params(axis='x', which='major', pad=0, labelsize=labsize)
#ax1.tick_params(axis='y', which='major', pad=1, labelsize=labsize)

#divider1 = make_axes_locatable(ax1)
#
#cax1 = divider1.append_axes("right", size="5%", pad=0.1)
#cbar1 = plt.colorbar(im1, cax=cax1)
#cbar1.ax.tick_params(labelsize=12)
#for l in cbar1.ax.yaxis.get_ticklabels():
#    l.set_family("Times New Roman")

for tick in ax1.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)
for tick in ax1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)

plt.savefig("../toy_model.png",dpi=200)
plt.show()

# %%
# Detectando as inclinações presentes no modelo
#pmin=-3
#pmax=3
#dp=0.1
#
#S,pmaxS,taumaxS,smax,ip,itau = SlantStack.slant_stack(pmin,pmax,dp,0,nz*dz,dz,MOD.T,dx,dz,0,0)
#
#plt.imshow(S,extent=[pmin,pmax,nz*dz,0],aspect="auto")
#plt.colorbar()
#plt.xlabel('p')
#plt.ylabel('tau')
#plt.show()

# %%
#t1 = np.degrees(np.arctan(pmaxS))
#print("pmax MOD1 =", pmaxS)
#print(f"theta 1 = {t1} graus")

# %%
#Modelo de Vagarosidade SW
#c = 250
SW=np.ones([nz,ntr])*1/c
print(SW.shape)

plt.imshow(SW)
plt.colorbar()
plt.show()
# Out:
# (120, 240)

# %%
#Tabela de tempo de trânsito do modelo de vagarosidade SW

#TT=MigPreFuncoes.raymodel3(SW,dx,ntr,"Data/time_table_barra.npy")

# %%
with open('../Data/time_table_barra.npy', 'rb') as f:
    TTh = np.load(f)

print(f"TTh.shape={TTh.shape}")

dt=0.004

TSX = (TTh[120,:,:])  # Traveltime  (indexes)
plt.imshow(TSX,extent=[0, ntr*dx, nz*dz, 0], aspect='auto')
plt.colorbar()
plt.show()

timer=np.round(TTh/dt)+1

print(f"TSX.shape={TSX.shape}")
# Out:
# TTh.shape=(240, 120, 240)
# TSX.shape=(120, 240)

# %%
print(np.shape(TSX))
# Out:
# (120, 240)

# %%
csfont = {'fontname':'Times New Roman'}
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax1 = plt.subplots(1,1,figsize=(8,6))

ftsize=23

im1 = ax1.imshow(TSX,extent=[0, ntr*dx, nz*dz, 0], aspect='auto', cmap="Greys", interpolation="bicubic")
ax1.set_ylabel("Depth (m)", **csfont, fontsize=ftsize)
ax1.set_xlabel("Distance (m)", **csfont, fontsize=ftsize)

#ax1.set_ylabel("Depth (m)", **csfont, fontsize=17)
#ax1.set_xlabel("Distância (m)", **csfont, fontsize=17)

labsize=19

ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')
#ax1.tick_params(axis='x', which='major', pad=0, labelsize=labsize)
#ax1.tick_params(axis='y', which='major', pad=1, labelsize=labsize)

divider1 = make_axes_locatable(ax1)

cax1 = divider1.append_axes("right", size="5%", pad=0.2)
cbar1 = plt.colorbar(im1, cax=cax1)
cbar1.ax.tick_params(labelsize=15)
for l in cbar1.ax.yaxis.get_ticklabels():
    l.set_family("Times New Roman")

for tick in ax1.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)
for tick in ax1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)

plt.savefig("../toy_model_tt.png",dpi=200)
plt.show()

# %%
dt=0.004
print(1/2/dt)
# Out:
# 125.0

# %%
#Wavelet

fr=40 #Hz
nps=200 #era 200, mudei pra 136 e funcionou, 
#       #tenho que conferir se posso fazer isso mesmo...
dt=.004 #s
rick=MigPreFuncoes.ricker(nps,fr,dt)

#sx=10  #index position
#sz=0  #index position

# Tempo de ida e volta até o fundo do modelo
tmax = np.sqrt((dx*nx)**2+(dz*nz)**2)*2/c
nt=int(np.ceil(tmax/dt+1))
print(tmax)
#nd2=nt+1; 



W=np.zeros(2*nt);
W[nt:nt+nps-1]=rick[0:nps-1]


plt.plot(np.arange(-nt*dt,nt*dt,dt),W)
plt.xlabel('s')
# Out:
# 2.146625258399798
# Text(0.5, 0, 's')

# %%
np.shape(W)
# Out:
# (1076,)

# %%
nx=ntr

#Modelo:
R = MOD.T

plt.imshow(R)
plt.show()

# %%
######### PAREI AQUI!!!!! RODAR ISSO AQUI!!!!!!

# %%
#Creating the synthetic csg

dsx = 1
nsx = nx
ngx = nx
path = "Data/CSG_diffbar/barra_gather_shot"

#files = MigPreFuncoes.kirchoffModeling(nsx,ngx,dsx,nx,nt,dt,TTh,R,W,path)

# %%
files = []

for i in range(240):
    filename = '../Data/CSG_diffbar/barra_gather_shot_{}'.format(i)
    #print(i,filename)
    with open(filename, 'rb') as file:
        (gather) = np.load(file)
        files.append(gather)
        
len(files)
# Out:
# 240

# %%
plt.imshow(files[120],aspect='auto',extent=[0, nx*dx, nt*dt, 0])

plt.xlabel('Distancia (m)')
plt.ylabel('Tempo (s)')
#plt.ylim([0.4,0])
plt.show()

# %%
fig, ax1 = plt.subplots(1,1,figsize=(8,6))

ftsize=23

im1 = ax1.imshow(files[120], aspect='auto', extent=[0, nx*dx, nt*dt, 0], cmap="gray", interpolation="bicubic")
ax1.set_ylabel("Time (s)", **csfont, fontsize=ftsize)
ax1.set_xlabel("Distance (m)", **csfont, fontsize=ftsize)

labsize=19

ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')

for tick in ax1.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)
for tick in ax1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)

plt.savefig("../toy_model_gather.png",dpi=200)
plt.show()

# %%
shot = 120
filename = 'Data/CSG_diffbar/barra_gather_shotCenter{}'.format(int(shot))

with open(filename, 'rb') as file:
    gather1t = np.load(file)

#nt=500
print(nt)
gather1=gather1t[0:nt,:]
win=20*dt
dwin=dt
app=15
isx=shot


plt.imshow(gather1,aspect='auto',extent=[0, nx*dx, nt*dt, 0])
plt.ylim([1,0])
plt.xlabel('Distancia (m)')
plt.ylabel('Tempo (s)')
plt.show()
# Out:
# 538

# %% [markdown]
# # Slant Stack

# %%
#Transformar em célula de código se não tiver o aruivo salvo localmente

pmin = -1
pmax = 1
dp = 0.1
xwin=zwin=30
dx=dz=1
x_ini=z_ini=0

#pm,sm = SlantStack.local_window(MOD.T,xwin,zwin,x_ini,z_ini,dx,dz,pmin,pmax,dp)

with open("Data/CSG_diffbar/barra_dipfield", "wb") as f:
    np.save(f,pm)
    
with open("Data/CSG_diffbar/barra_semblance", "wb") as f: 
    np.save(f,sm)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [01:03<00:00,  1.88it/s]

# %%
with open("../Data/CSG_diffbar/barra_dipfield", "rb") as f:
    pm = np.load(f)
    
with open("../Data/CSG_diffbar/barra_semblance", "rb") as f: 
    sm = np.load(f)

from mpl_toolkits.axes_grid1 import make_axes_locatable

fig = plt.figure(figsize=(10, 10))

ax1 = fig.add_subplot(121)
ax1.set_title("Ângulos pmax (em tangente)")
ax1.set_xlabel("Distancia (m)")
ax1.set_ylabel("Profundidade (m)")
im1 = ax1.imshow(pm,extent=[0, nx*dx, nz*dz, 0])
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='10%', pad=0.1)
fig.colorbar(im1, cax=cax, orientation='vertical')


ax2 = fig.add_subplot(122)
ax2.set_title("Semblance")
ax2.set_xlabel("Distancia (m)")
ax2.set_ylabel("Profundidade (m)")
im2 = ax2.imshow(sm,extent=[0, nx*dx, nz*dz, 0])
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='10%', pad=0.1)
fig.colorbar(im2, cax=cax, orientation='vertical')

plt.tight_layout()
plt.show()

# %%
csfont = {'fontname':'Times New Roman'}
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax1 = plt.subplots(1,1,figsize=(8,6))

ftsize=23

im1 = ax1.imshow(np.abs(X),extent=[0, ntr*dx, nz*dz, 0], aspect='auto', cmap="Greys", interpolation="bicubic")
ax1.set_ylabel("Depth (m)", **csfont, fontsize=ftsize)
ax1.set_xlabel("Distance (m)", **csfont, fontsize=ftsize)

labsize=19

ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')

divider1 = make_axes_locatable(ax1)

cax1 = divider1.append_axes("right", size="5%", pad=0.2)
cbar1 = plt.colorbar(im1, cax=cax1)
cbar1.ax.tick_params(labelsize=15)
for l in cbar1.ax.yaxis.get_ticklabels():
    l.set_family("Times New Roman")

for tick in ax1.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)
for tick in ax1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)

plt.savefig("../toy_model_pm.png",dpi=200)
plt.show()

# %%
csfont = {'fontname':'Times New Roman'}
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax1 = plt.subplots(1,1,figsize=(8,6))

ftsize=23

im1 = ax1.imshow(sm,extent=[0, ntr*dx, nz*dz, 0], aspect='auto', cmap="Greys", interpolation="bicubic")
ax1.set_ylabel("Depth (m)", **csfont, fontsize=ftsize)
ax1.set_xlabel("Distance (m)", **csfont, fontsize=ftsize)

labsize=19

ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')

divider1 = make_axes_locatable(ax1)

cax1 = divider1.append_axes("right", size="5%", pad=0.2)
cbar1 = plt.colorbar(im1, cax=cax1)
cbar1.ax.tick_params(labelsize=15)
for l in cbar1.ax.yaxis.get_ticklabels():
    l.set_family("Times New Roman")

for tick in ax1.get_xticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)
for tick in ax1.get_yticklabels():
    tick.set_fontname("Times New Roman")
    tick.set_fontsize(labsize)

plt.savefig("../toy_model_sm.png",dpi=200)
plt.show()

# %%
m_theta = np.arctan(pm)
plt.imshow(m_theta,extent=[0, ntr*dx, nz*dz, 0], aspect="auto")
plt.title("Ângulos")
plt.colorbar()
plt.show()

# %%
X = np.sin(m_theta)
Y = np.cos(m_theta)

fig = plt.figure(figsize=(8, 8))

ax1 = fig.add_subplot(121)
ax1.set_title("Componente X")
ax1.set_xlabel("Distancia (m)")
ax1.set_ylabel("Profundidade (m)")
im1 = ax1.imshow(X)
divider = make_axes_locatable(ax1)
cax = divider.append_axes('right', size='10%', pad=0.1)
fig.colorbar(im1, cax=cax, orientation='vertical')


ax2 = fig.add_subplot(122)
ax2.set_title("Componente Y")
ax2.set_xlabel("Distancia (m)")
ax2.set_ylabel("Profundidade (m)")
im2 = ax2.imshow(Y)
divider = make_axes_locatable(ax2)
cax = divider.append_axes('right', size='10%', pad=0.1)
fig.colorbar(im2, cax=cax, orientation='vertical')

plt.tight_layout()
plt.show()

# %%
##migração com peso=w

# %%
import importlib
importlib.reload(MigPreFuncoes)

win=10*dt #(metade)janela em tempo em cada etapa
dwin=dt

app=40 # abertura em traços

refl,diff = MigPreFuncoes.kirchhoffMigration(gather1,isx,dx,dz,dt,
                                         win,dwin,app,TTh,X,Y)


fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(13,4))

ax1.imshow(refl, aspect="auto",extent=[0,dx*nx,dz*nz,0],interpolation="bicubic")
ax1.set_title("Imagem Migrada Convencional")
ax1.set_xlabel("Distancia (m)")
ax1.set_ylabel("Profundidade (m)")

ax2.imshow(diff, aspect="auto",extent=[0,dx*nx,dz*nz,0],interpolation="bicubic")
ax2.set_title("Imagem de Difrações")
ax2.set_xlabel("Distancia (m)")
ax2.set_ylabel("Profundidade (m)")

ax3.imshow(R, aspect="auto",extent=[0,dx*nx,dz*nz,0])
ax3.set_title("Modelo Original")
ax3.set_xlabel("Distancia (m)")
ax3.set_ylabel("Profundidade (m)")

plt.tight_layout()
plt.show()
# Out:
# Imported MigPreFuncoes now
# 1 1
# 100%|████████████████████████████████████████████████████████████████████████████████| 240/240 [00:59<00:00,  4.04it/s]

# %%
##Agora usando a semblance como peso e w**2

# %%
refl,diff = MigPreFuncoes.migration_teste(gather1,isx,dx,dz,dt,win,dwin,app,TTh,X,Y,sm)

fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(13,4))

ax1.imshow(refl, aspect="auto",extent=[0,dx*nx,dz*nz,0])
ax1.set_title("Imagem Migrada Convencional")
ax1.set_xlabel("Distancia (m)")
ax1.set_ylabel("Profundidade (m)")

ax2.imshow(diff, aspect="auto",extent=[0,dx*nx,dz*nz,0])
ax2.set_title("Imagem Migrada Difrações")
ax2.set_xlabel("Distancia (m)")
ax2.set_ylabel("Profundidade (m)")

ax3.imshow(R, aspect="auto",extent=[0,dx*nx,dz*nz,0])
ax3.set_title("Modelo Original")
ax3.set_xlabel("Distancia (m)")
ax3.set_ylabel("Profundidade (m)")

plt.tight_layout()
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 240/240 [00:59<00:00,  4.03it/s]

# %%
##stack de migrações com peso=w

# %%
refl,diff = MigPreFuncoes.kirchhoffMigration(files,isx,dx,dz,dt,
                                         win,dwin,app,TTh,X,Y)


fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(13,4))

ax1.imshow(refl, aspect="auto",extent=[0,dx*nx,dz*nz,0],interpolation="bicubic")
ax1.set_title("Imagem Migrada Convencional")
ax1.set_xlabel("Distancia (m)")
ax1.set_ylabel("Profundidade (m)")

ax2.imshow(diff, aspect="auto",extent=[0,dx*nx,dz*nz,0],interpolation="bicubic")
ax2.set_title("Imagem de Difrações")
ax2.set_xlabel("Distancia (m)")
ax2.set_ylabel("Profundidade (m)")

ax3.imshow(R, aspect="auto",extent=[0,dx*nx,dz*nz,0])
ax3.set_title("Modelo Original")
ax3.set_xlabel("Distancia (m)")
ax3.set_ylabel("Profundidade (m)")

plt.tight_layout()
plt.show()
# Out:
# 228it [18:22:50, 1881.27s/it]
